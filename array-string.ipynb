# %%
def hello(i):
    if i == 1:
        return 1
    if i == 2:
        return 2
    else:
        return -1

# %%
from util import test

tests = [
    test.Test(1, expected=1),
    test.Test(2, expected=2),
    test.Test(3, expected=-1)
] 

test.run(hello, tests)
# Out:
# Running hello...
#
#   ✓ Test 1
#   ✓ Test 2
#   ✓ Test 3
#
# Result: 3/3 passed
# True

# %%
from util import benchmark

benchmark.run(
    {
        "he3llo": hello
    },
    [[1],
    [2],
    [3]],
    runs=9
)
# Out:
# Benchmark
# ...
#
# Solution                      Average      Median         Min
# -------------------------------------------------------------
# he3llo                        0.009 ms     0.010 ms     0.008 ms
#
# Fastest: he3llo

# %%
help(test.run)
# Out:
# Help on function run in module util.test:
#
# run(
#     solution: Callable,
#     tests: list[util.test.Test],
#     *,
#     name: str | None = None,
#     normalize: Optional[Callable[[Any], Any]] = None
# )
#     Run a LeetCode solution against a collection of test cases.
#
#     Example:
#
#         tests = [
#             Test([2, 7, 11, 15], 9),
#             Test([3, 2, 4], 6),
#         ]
#
#         run(Solution().twoSum, tests)
#
#     `normalize` can be used when the ordering of the result doesn't matter:
#
#         run(
#             Solution().threeSum,
#             tests,
#             normalize=lambda x: sorted(sorted(v) for v in x)
#         )

# %%
help(benchmark)
# Out:
# Help on module util.benchmark in util:
#
# NAME
#     util.benchmark - # util/benchmark.py
#
# CLASSES
#     builtins.object
#         BenchmarkResult
#
#     class BenchmarkResult(builtins.object)
#      |  BenchmarkResult(name: str, times: list[float]) -> None
#      |
#      |  BenchmarkResult(name: str, times: list[float])
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |      Return self==value.
#      |
#      |  __init__(self, name: str, times: list[float]) -> None
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __replace__ = _replace(self, /, **changes) from dataclasses
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  average
#      |
#      |  median
#      |
#      |  minimum
#      |
# ...
